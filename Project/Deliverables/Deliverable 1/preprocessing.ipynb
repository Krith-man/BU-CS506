# %% [markdown]
# # Preprocess Mars2021

# %%
import pandas as pd
import numpy as np
df = pd.read_csv("Mars2021_Data.csv")

######### Questions processed #########

# Question 4 about gender:
"""
 Turn Hyper-Masculine -> 1
 Turn Masculine -> 2
 Turn Feminine -> 4
""" 
df["Q4_Gender"].replace({"Hyper-Masculine": "1"}, inplace=True)
df["Q4_Gender"].replace({"Masculine": "2"}, inplace=True)
df["Q4_Gender"].replace({"Feminine": "4"}, inplace=True)

# Question 7 about gender:
"""
 Turn choice 7 'South Asian/ Indian (not Native American)' to 5 'Asian/Asian American'
""" 
df["Q7_Race_Ethnicity"].replace({7: 5}, inplace=True)

# Question 8,9,10 about physically, cognitively and communication disabled
"""
Merge them into one.
"""
df = df.rename(columns={"Q8_Physical_Disability": "Q8_Disability"})
df = df.drop("Q9_Cognitive_Disability", axis=1)
df = df.drop("Q10_Communication_Disability", axis=1)

# Rename question 11 to question 9
df = df.rename(columns={"Q11a_Shopping": "Q9a_Shopping"})
df = df.rename(columns={"Q11b_Driving": "Q9b_Driving"})
df = df.rename(columns={"Q11c_Cleaning": "Q9c_Cleaning"})
df = df.rename(columns={"Q11d_Cooking": "Q9d_Cooking"})
df = df.rename(columns={"Q11e_Working": "Q9e_Working"})
df = df.rename(columns={"Q11f_Socializing": "Q9f_Socializing"})
df = df.rename(columns={"Q11g_Nothing": "Q9g_Nothing"})
df = df.rename(columns={"Q11h_Eating/Drinking": "Q9h_Eating/Drinking"})
df = df.rename(columns={"Q11i_Exercising": "Q9i_Exercising"})
df = df.rename(columns={"Q11j_Activity Other": "Q9j_Activity Other"})
df = df.rename(columns={"Q11j_Activity_Other_Specify": "Q9j_Activity_Other_Specify"})

# Rename question 12 to question 10
df = df.rename(columns={"Q12a_Kitchen": "Q10a_Kitchen"})
df = df.rename(columns={"Q12b_Office": "Q10b_Office"})
df = df.rename(columns={"Q12c_Car": "Q10c_Car"})
df = df.rename(columns={"Q12d_Store": "Q10d_Store"})
df = df.rename(columns={"Q12e_Outdoors": "Q10e_Outdoors"})
df = df.rename(columns={"Q12f_Living Room": "Q10f_Living Room"})
df = df.rename(columns={"Q12g_Restaurant_Bar": "Q10g_Restaurant_Bar"})
df = df.rename(columns={"Q12h_Gym": "Q10h_Gym"})
df = df.rename(columns={"Q12i_Bedroom": "Q10i_Bedroom"})
df = df.rename(columns={"Q12j_Bathroom": "Q10j_Bathroom"})
df = df.rename(columns={"Q12k_Sporting_Event": "Q10k_Sporting_Event"})
df = df.rename(columns={"Q12l_Classroom": "Q10l_Classroom"})
df = df.rename(columns={"Q12m_Location_Other": "Q10m_Location_Other"})
df = df.rename(columns={"Q12m_Location_Other_Specify": "Q10m_Location_Other_Specify"})

# Rename question 13 to question 11
df = df.rename(columns={"Q13_Revealing_Clothing": "Q11_Revealing_Clothing"})

# Rename question 14 to question 12
df = df.rename(columns={"Q14_Nudity": "Q12_Nudity"})
df = df.rename(columns={"Q14a_Nudity_Other_Specify": "Q12a_Nudity_Other_Specify"})

# Rename question 15 to question 13
df = df.rename(columns={"Q15_Visually_Objectified": "Q13_Visually_Objectified"})

# Rename question 16 to question 14
df = df.rename(columns={"Q16_Verbally_Objectified": "Q14_Verbally_Objectified"})

# Rename question 17 to question 15
df = df.rename(columns={"Q17_Intelligence": "Q15_Intelligence"})

# Rename question 18 to question 16
df = df.rename(columns={"Q18_Humor": "Q16_Humor"})

# Rename question 19 to question 17
df = df.rename(columns={"Q19_Occupation": "Q17_Occupation"})

# Rename question 20 to question 18
df = df.rename(columns={"Q20_Leader": "Q18_Leader"})

# Rename question 21 to question 19
df = df.rename(columns={"Q21_Authority": "Q19_Authority"})

# Rename question 22 to question 20
df = df.rename(columns={"Q22_Body Type": "Q20_Body Type"})
df = df.rename(columns={"Q22a_Body_Type_Other_Specify": "Q20a_Body_Type_Other_Specify"})

# Rename question 23 to question 21
df = df.rename(columns={"Q23a_Disordered_Eating": "Q21a_Disordered_Eating"})
df = df.rename(columns={"Q23b_Selfy_injury": "Q21b_Selfy_injury"})
df = df.rename(columns={"Q23c_NegativeTalk": "Q21c_NegativeTalk"})
df = df.rename(columns={"Q23d_Body_Modification": "Q21d_Body_Modification"})

# Rename question 24 to question 22
df = df.rename(columns={"Q24a_Visual_Shame": "Q22a_Visual_Shame"})
df = df.rename(columns={"Q24b_Verbal_shame": "Q22b_Verbal_Shame"})
df = df.rename(columns={"Q24c_Sizeist_Slurs": "Q22c_Sizeist_Slurs"})
df = df.rename(columns={"Q24d_Punchline": "Q22d_Punchline"})
df = df.rename(columns={"Q24e_Denied_Personal_Opportunity": "Q22e_Denied_Personal_Opportunity"})
df = df.rename(columns={"Q24f_Denied_Professional_Opportunity": "Q22f_Denied_Professional_Opportunity"})
df = df.rename(columns={"Q24g_Other_Prejudice": "Q22g_Other_Prejudice"})
df = df.rename(columns={"Q24g_Prejudice_Other_Specify": "Q22g_Prejudice_Other_Specify"})

# Rename question 25 to question 23
df = df.rename(columns={"Q25a_Lazy": "Q23a_Lazy"})
df = df.rename(columns={"Q25b_Physically_Slow": "Q23b_Physically_Slow"})
df = df.rename(columns={"Q25c_Stupid": "Q23c_Stupid"})
df = df.rename(columns={"Q25d_Loser": "Q23d_Loser"})
df = df.rename(columns={"Q25e_Inactive": "Q23e_Inactive"})
df = df.rename(columns={"Q25f_Poorly_Dressed": "Q23f_Poorly_Dressed"})
df = df.rename(columns={"Q25g_Funny": "Q23g_Funny"})
df = df.rename(columns={"Q25h_Jolly": "Q23h_Jolly"})
df = df.rename(columns={"Q25i_Clumsy": "Q23i_Clumsy"})
df = df.rename(columns={"Q25j_Alone": "Q23j_Alone"})

# Rename question 26 to question 24
df = df.rename(columns={"Q26a_Comic_Relief": "Q24a_Comic_Relief"})
df = df.rename(columns={"Q26b_Sidekick": "Q24b_Sidekick"})
df = df.rename(columns={"Q26c_Mamma_Hen": "Q24c_Mamma_Hen"})
df = df.rename(columns={"Q26d_Nympho": "Q24d_Nympho"})

# Rename question 27 to question 25
df = df.rename(columns={"Q27_Fat_to_Fit": "Q25_Fat_to_Fit"})
df = df.rename(columns={"Q27. NOTES": "Q27_NOTES"})


# Rename question 28 to question 26
df = df.rename(columns={"Q28_Inspo_Porn": "Q26_Inspo_Porn"})

# Drop unrelated columns
df = df.drop(['Unnamed: 88','Unnamed: 90','Unnamed: 92','Unnamed: 93','Unnamed: 94','Unnamed: 95','Unnamed: 96','Unnamed: 97','Unnamed: 98','Unnamed: 99','Unnamed: 100','Unnamed: 101','Unnamed: 102','Unnamed: 103','Unnamed: 104','Unnamed: 105','Unnamed: 106'], axis=1)

# %%
# Fix Year_Aired to be one year before the dataset name e.g Mars2021 -> 2020
df = df[df['Year_Aired'] == 2020]
# Fix Segment inconsistent values from "Pet" to be all "Petcare"
df["Segment"].replace({"Pet": "Petcare"}, inplace=True)

# Save preprocessed dataset 
df.to_csv("Preprocessed_Mars2021_Data.csv", encoding='utf-8', index=False)
df.head()
# Out:
#         Coder                                        Asset_Name  \
# 19       Emma  Airwaves 2020 Intense Mint launch campaign video
# 36     Pamela                                      BOOMER BICEP
# 37  CEspinoza                                    BOOMER RAMAYAN
# 38  CEspinoza                                    BOOMER RAMAYAN
# 39     CAckel                                  BOOMER FISH BOWL
#
#               Brand Lead_Country  Year_Produced  Year_Aired        Segment  \
# 19  Airwaves          NORTH ASIA           2020        2020  Confectionary
# 36           BOOMER        India           2020        2020  Confectionary
# 37           BOOMER        India           2020        2020  Confectionary
# 38           BOOMER        India           2020        2020  Confectionary
# 39           BOOMER        India           2020        2020  Confectionary
#
#    Agency         Character_Name              Character_Description  ...  \
# ...

# %% [markdown]
# # Preprocess Mars2020

# %%
df = pd.read_csv("Mars2020_Data.csv")
df.head()
# Out:
#     Coder                   AssetName  Brand LeadCountry  Yearproduced  \
# 0  Soraya                    Ball Bag  M&M's      France          2018
# 1  Soraya             Casting Aquaman  M&M's      France          2018
# 2  Soraya  Casting Mission Impossible  M&M's      France          2018
# 3  Soraya  Casting Mission Impossible  M&M's      France          2018
# 4  Soraya                      Header  M&M's      France          2018
#
#    yearAired        Segment CharacterName CharacterDescription  Q1.PROMINENCE  \
# 0       2018  Confectionary       red m&m                                   1
# 1       2018  Confectionary       red m&m                                   1
# 2       2018  Confectionary       red m&m                                   1
# 3       2018  Confectionary    yellow m&m                                   1
# 4       2018  Confectionary       red m&m                                   1
#
# ...

# %%
df = df.rename(columns={"AssetName": "Asset_Name"})
df = df.rename(columns={"LeadCountry": "Lead_Country"})
df = df.rename(columns={"Yearproduced": "Year_Produced"})
df = df.rename(columns={"yearAired": "Year_Aired"})
# Add Agency to specific place as Mars2021 dataset 
df.insert(loc=7, column='Agency', value="")
df = df.rename(columns={"CharacterName": "Character_Name"})
df = df.rename(columns={"CharacterDescription": "Character_Description"})
df = df.rename(columns={"Q1.PROMINENCE": "Q1_Prominence"})
df = df.rename(columns={"Q2.AGE": "Q2_Age"})
df = df.rename(columns={"Q2a.AgeOtherSpecify": "Q2a_Age_SpecifyOther"})
df = df.rename(columns={"Q3.SEX": "Q3_Sex"})
df = df.rename(columns={"Q4.GENDER": "Q4_Gender"})
df = df.rename(columns={"Q5.LGBTQ": "Q5_LGBTQ"})
df = df.rename(columns={"Q6.ANIMATED": "Q6_Animated"})
df = df.rename(columns={"Q6a.AnimatedOtherSpecify": "Q6a_Animated_OtherSpecify"})
df = df.rename(columns={"Q7.RACEETHNICITY": "Q7_Race_Ethnicity"})
# Question 7 about gender:
"""
 Turn choice 7 'South Asian/ Indian (not Native American)' to 5 'Asian/Asian American'
""" 
df["Q7_Race_Ethnicity"].replace({7: 5}, inplace=True)
df = df.rename(columns={"Q7a.RaceEthnicityOtherSpecify": "Q7a_RE_OtherSpecify"})
df = df.rename(columns={"Q8.PHYSICALDISABILITY": "Q8_Disability"})
df = df.drop("Q9.COGNITIVEDISABILITY", axis=1)
df = df.drop("Q10.COMMUNICATIONDISABILITY", axis=1)
df = df.rename(columns={"Q11a.SHOPPING": "Q9a_Shopping"})
df = df.rename(columns={"Q11b.DRIVING": "Q9b_Driving"})
df = df.rename(columns={"Q11c.CLEANING": "Q9c_Cleaning"})
df = df.rename(columns={"Q11d.COOKING": "Q9d_Cooking"})
df = df.rename(columns={"Q11e.WORKING": "Q9e_Working"})
df = df.rename(columns={"Q11f.SOCIALIZING": "Q9f_Socializing"})
df = df.rename(columns={"Q11g.NOTHING": "Q9g_Nothing"})
df = df.rename(columns={"Q11h.EATINGDRINKING": "Q9h_Eating/Drinking"})
df = df.rename(columns={"Q11i.EXERCISING": "Q9i_Exercising"})
df = df.rename(columns={"Q11j.ACTIVITYOTHER": "Q9j_Activity Other"})
df = df.rename(columns={"Q11j.ActivityOtherSpecify": "Q9j_Activity_Other_Specify"})
df = df.rename(columns={"Q12a.KITCHEN": "Q10a_Kitchen"})
df = df.rename(columns={"Q12b.OFFICE": "Q10b_Office"})
df = df.rename(columns={"Q12c.CAR": "Q10c_Car"})
df = df.rename(columns={"Q12d.STORE": "Q10d_Store"})
df = df.rename(columns={"Q12e.OUTDOORS": "Q10e_Outdoors"})
df = df.rename(columns={"Q12f.LIVINGROOM": "Q10f_Living Room"})
df = df.rename(columns={"Q12g.RESTAURANTBAR": "Q10g_Restaurant_Bar"})
df = df.rename(columns={"Q12h.GYM": "Q10h_Gym"})
df = df.rename(columns={"Q12i.BEDROOM": "Q10i_Bedroom"})
df = df.rename(columns={"Q12j.BATHROOM": "Q10j_Bathroom"})
df = df.rename(columns={"Q12k.SPORTINGEVENT": "Q10k_Sporting_Event"})
df = df.rename(columns={"Q12l.CLASSROOM": "Q10l_Classroom"})
df = df.rename(columns={"Q12m.LOCATIONOTHER": "Q10m_Location_Other"})
df = df.rename(columns={"Q12m.LocationOtherSpecify": "Q10m_Location_Other_Specify"})
df = df.rename(columns={"Q13.REVEALINGCLOTHING": "Q11_Revealing_Clothing"})
df = df.rename(columns={"Q14.NUDITY": "Q12_Nudity"})
df = df.rename(columns={"Q14a.NudityOtherSpecify": "Q12a_Nudity_Other_Specify"})
df = df.rename(columns={"Q15.VISUALLYOBJECTIFIED": "Q13_Visually_Objectified"})
df = df.rename(columns={"Q16.VERBALLYOBJECTIFIED": "Q14_Verbally_Objectified"})
df = df.rename(columns={"Q17.INTELLIGENCE": "Q15_Intelligence"})
df = df.rename(columns={"Q18.HUMOR": "Q16_Humor"})
df = df.rename(columns={"Q19.OCCUPATION": "Q17_Occupation"})
df = df.rename(columns={"Q20.LEADER": "Q18_Leader"})
df = df.rename(columns={"Q21.AUTHORITY": "Q19_Authority"})
df = df.rename(columns={"Q22.BODYTYPE": "Q20_Body Type"})
df = df.rename(columns={"Q22a.BodyTypeOtherSpecify": "Q20a_Body_Type_Other_Specify"})
df = df.rename(columns={"Q23a.DISORDEREDEATING": "Q21a_Disordered_Eating"})
df = df.rename(columns={"Q23b.SELFINJURY": "Q21b_Selfy_injury"})
df = df.rename(columns={"Q23c.NEGATIVETALK": "Q21c_NegativeTalk"})
df = df.rename(columns={"Q23d.BODYMODIFICATION": "Q21d_Body_Modification"})
df = df.rename(columns={"Q24a.VISUALSHAME": "Q22a_Visual_Shame"})
df = df.rename(columns={"Q24b.VERBALSHAME": "Q22b_Verbal_Shame"})
df = df.rename(columns={"Q24c.SIZEISTSLURS": "Q22c_Sizeist_Slurs"})
df = df.rename(columns={"Q24d.PUNCHLINE": "Q22d_Punchline"})
df = df.rename(columns={"Q24e.DENIEDPERSONALOPPORTUNITIES": "Q22e_Denied_Personal_Opportunity"})
df = df.rename(columns={"Q24f.DENIEDPROFESSIONALOPPORTUNITIES": "Q22f_Denied_Professional_Opportunity"})
df = df.rename(columns={"Q24g.OTHERPREJUDICE": "Q22g_Other_Prejudice"})
df = df.rename(columns={"Q24g.PrejudiceOtherSpecify": "Q22g_Prejudice_Other_Specify"})
df = df.rename(columns={"Q25a.LAZY": "Q23a_Lazy"})
df = df.rename(columns={"Q25b.PHYSICALLYSLOW": "Q23b_Physically_Slow"})
df = df.rename(columns={"Q25c.STUPID": "Q23c_Stupid"})
df = df.rename(columns={"Q25d.LOSER": "Q23d_Loser"})
df = df.rename(columns={"Q25e.INACTIVE": "Q23e_Inactive"})
df = df.rename(columns={"Q25f.POORLYDRESSED": "Q23f_Poorly_Dressed"})
df = df.rename(columns={"Q25g.FUNNY": "Q23g_Funny"})
df = df.rename(columns={"Q25h.JOLLY": "Q23h_Jolly"})
df = df.rename(columns={"Q25i.CLUMSY": "Q23i_Clumsy"})
df = df.rename(columns={"Q25j.ALONE": "Q23j_Alone"})
df = df.rename(columns={"Q26a.COMICRELIEF": "Q24a_Comic_Relief"})
df = df.rename(columns={"Q26b.SIDEKICK": "Q24b_Sidekick"})
df = df.rename(columns={"Q26c.MAMMAHEN": "Q24c_Mamma_Hen"})
df = df.rename(columns={"Q26d.NYMPHO": "Q24d_Nympho"})
df = df.rename(columns={"Q27.FATTOFIT": "Q25_Fat_to_Fit"})
df = df.rename(columns={"Q28.INSPOPORN": "Q26_Inspo_Porn"})
df["Q27_NOTES"] = ""
df["Notes on Dwelling"] = ""

# %%
# Fix Year_Aired to be one year before the dataset name e.g Mars2021 -> 2020
df = df[df['Year_Aired'] == 2019]
# Save preprocessed dataset 
df.to_csv("Preprocessed_Mars2020_Data.csv", encoding='utf-8', index=False)
df.head()
# Out:
#      Coder               Asset_Name  Brand    Lead_Country  Year_Produced  \
# 10  Soraya  Spiderman Far From Home  M&M's  Global Toolkit           2019
# 11  Soraya  Spiderman Far From Home  M&M's  Global Toolkit           2019
# 14  Soraya                    Drone  M&M's          Arabia           2019
# 15  Soraya                 Surprise  M&M's          Arabia           2019
# 22   Sofia       Out of Order (:15)   Twix             USA           2019
#
#     Year_Aired        Segment Agency Character_Name Character_Description  \
# 10        2019  Confectionary               red m&m
# 11        2019  Confectionary            yellow m&m
# 14        2019  Confectionary               red m&m
# 15        2019  Confectionary               red m&m
# 22        2019  Confectionary                  Bill
#
#     ...  Q23i_Clumsy  Q23j_Alone Q24a_Comic_Relief  Q24b_Sidekick  \
# 10  ...
# 11  ...
# 14  ...
# 15  ...
# 22  ...
#
# ...

# %% [markdown]
# # Merge Mars2020 & Mars2021

# %%
df1 = pd.read_csv("Preprocessed_Mars2021_Data.csv")
df2 = pd.read_csv("Preprocessed_Mars2020_Data.csv")

# %%
print(df1.columns.tolist())
len(df1)
# Out:
# ['Coder', 'Asset_Name', 'Brand', 'Lead_Country', 'Year_Produced', 'Year_Aired', 'Segment', 'Agency', 'Character_Name', 'Character_Description', 'Q1_Prominence', 'Q2_Age', 'Q2a_Age_SpecifyOther', 'Q3_Sex', 'Q4_Gender', 'Q5_LGBTQ', 'Q6_Animated', 'Q6a_Animated_OtherSpecify', 'Q7_Race_Ethnicity', 'Q7a_RE_OtherSpecify', 'Q8_Disability', 'Q9a_Shopping', 'Q9b_Driving', 'Q9c_Cleaning', 'Q9d_Cooking', 'Q9e_Working', 'Q9f_Socializing', 'Q9g_Nothing', 'Q9h_Eating/Drinking', 'Q9i_Exercising', 'Q9j_Activity Other', 'Q9j_Activity_Other_Specify', 'Q10a_Kitchen', 'Q10b_Office', 'Q10c_Car', 'Q10d_Store', 'Q10e_Outdoors', 'Q10f_Living Room', 'Q10g_Restaurant_Bar', 'Q10h_Gym', 'Q10i_Bedroom', 'Q10j_Bathroom', 'Q10k_Sporting_Event', 'Q10l_Classroom', 'Q10m_Location_Other', 'Q10m_Location_Other_Specify', 'Q11_Revealing_Clothing', 'Q12_Nudity', 'Q12a_Nudity_Other_Specify', 'Q13_Visually_Objectified', 'Q14_Verbally_Objectified', 'Q15_Intelligence', 'Q16_Humor', 'Q17_Occupation', 'Q18_Leader', 'Q19_Authori
# ...

# %%
print(df2.columns.tolist())
len(df2)
# Out:
# ['Coder', 'Asset_Name', 'Brand', 'Lead_Country', 'Year_Produced', 'Year_Aired', 'Segment', 'Agency', 'Character_Name', 'Character_Description', 'Q1_Prominence', 'Q2_Age', 'Q2a_Age_SpecifyOther', 'Q3_Sex', 'Q4_Gender', 'Q5_LGBTQ', 'Q6_Animated', 'Q6a_Animated_OtherSpecify', 'Q7_Race_Ethnicity', 'Q7a_RE_OtherSpecify', 'Q8_Disability', 'Q9a_Shopping', 'Q9b_Driving', 'Q9c_Cleaning', 'Q9d_Cooking', 'Q9e_Working', 'Q9f_Socializing', 'Q9g_Nothing', 'Q9h_Eating/Drinking', 'Q9i_Exercising', 'Q9j_Activity Other', 'Q9j_Activity_Other_Specify', 'Q10a_Kitchen', 'Q10b_Office', 'Q10c_Car', 'Q10d_Store', 'Q10e_Outdoors', 'Q10f_Living Room', 'Q10g_Restaurant_Bar', 'Q10h_Gym', 'Q10i_Bedroom', 'Q10j_Bathroom', 'Q10k_Sporting_Event', 'Q10l_Classroom', 'Q10m_Location_Other', 'Q10m_Location_Other_Specify', 'Q11_Revealing_Clothing', 'Q12_Nudity', 'Q12a_Nudity_Other_Specify', 'Q13_Visually_Objectified', 'Q14_Verbally_Objectified', 'Q15_Intelligence', 'Q16_Humor', 'Q17_Occupation', 'Q18_Leader', 'Q19_Authori
# ...

# %%
df = pd.concat([df1, df2], ignore_index=True)
len(df)
# Out:
# 1287

# %%
df.to_csv("Merged_Preprocessed_Mars2020_2021.csv", encoding='utf-8', index=False)
